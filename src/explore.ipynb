# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import *
from imblearn.metrics import specificity_score

# %%
data=pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/k-means-project-tutorial/main/housing.csv")
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
x=data[["MedInc","Latitude","Longitude"]]
x
# Out:
#        MedInc  Latitude  Longitude
# 0      8.3252     37.88    -122.23
# 1      8.3014     37.86    -122.22
# 2      7.2574     37.85    -122.24
# 3      5.6431     37.85    -122.25
# 4      3.8462     37.85    -122.25
# ...       ...       ...        ...
# 20635  1.5603     39.48    -121.09
# 20636  2.5568     39.49    -121.21
# 20637  1.7000     39.43    -121.22
# 20638  1.8672     39.43    -121.32
# 20639  2.3886     39.37    -121.24
#
# [20640 rows x 3 columns]

# %%
X_train,X_test=train_test_split(x,test_size=0.2,random_state=42)
X_train
# Out:
#        MedInc  Latitude  Longitude
# 14196  3.2596     32.71    -117.03
# 8267   3.8125     33.77    -118.16
# 17445  4.1563     34.66    -120.48
# 14265  1.9425     32.69    -117.11
# 2271   3.5542     36.78    -119.80
# ...       ...       ...        ...
# 11284  6.3700     33.78    -117.96
# 11964  3.0500     34.02    -117.43
# 5390   2.9344     34.03    -118.38
# 860    5.7192     37.58    -121.96
# 15795  2.5755     37.77    -122.42
#
# [16512 rows x 3 columns]

# %%
model=KMeans(n_clusters = 6, random_state = 42)
model.fit(X_train)
y_train=list(model.labels_)
y_train
# Out:
# [np.int32(3),
#  np.int32(1),
#  np.int32(1),
#  np.int32(3),
#  np.int32(5),
#  np.int32(0),
#  np.int32(3),
#  np.int32(0),
#  np.int32(3),
#  np.int32(2),
#  np.int32(0),
#  np.int32(3),
#  np.int32(5),
#  np.int32(5),
#  np.int32(3),
#  np.int32(3),
#  np.int32(5),
#  np.int32(0),
#  np.int32(1),
#  np.int32(3),
#  np.int32(3),
#  np.int32(0),
#  np.int32(5),
#  np.int32(3),
#  np.int32(5),
#  np.int32(0),
#  np.int32(5),
#  np.int32(1),
#  np.int32(1),
#  np.int32(5),
#  np.int32(3),
#  np.int32(1),
#  np.int32(3),
#  np.int32(3),
#  np.int32(1),
#  np.int32(1),
#  np.int32(5),
#  np.int32(3),
#  np.int32(1),
#  np.int32(3),
#  np.int32(4),
#  np.int32(1),
#  np.int32(1),
#  np.int32(2),
#  np.int32(1),
#  np.int32(3),
#  np.int32(5),
#  np.int32(3),
#  np.int32(3),
#  np.int32(1),
#  np.int32(3),
#  np.int32(0),
#  np.int32(5),
#  np.int32(3),
#  np.int32(3),
#  np.int32(2),
#  np.int32(4),
#  np.int32(3),
#  np.int32(3),
#  np.int32(3),
#  np.int32(3),
#  np.int32(3),
# ...

# %%
X_train["cluster"]=y_train
X_train
# Out:
#        MedInc  Latitude  Longitude  cluster
# 14196  3.2596     32.71    -117.03        3
# 8267   3.8125     33.77    -118.16        1
# 17445  4.1563     34.66    -120.48        1
# 14265  1.9425     32.69    -117.11        3
# 2271   3.5542     36.78    -119.80        5
# ...       ...       ...        ...      ...
# 11284  6.3700     33.78    -117.96        2
# 11964  3.0500     34.02    -117.43        3
# 5390   2.9344     34.03    -118.38        3
# 860    5.7192     37.58    -121.96        0
# 15795  2.5755     37.77    -122.42        5
#
# [16512 rows x 4 columns]

# %%
plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
sns.scatterplot(data=X_train, x='Longitude', y='Latitude', hue='cluster', palette='viridis')
plt.title('X_train: Longitud vs Latitud')
plt.xlabel('Longitud')
plt.ylabel('Latitud')

# Gráfico 2: Histograma de la variable MedInc
plt.subplot(1, 3, 2)
sns.scatterplot(data=X_train, x='Longitude', y='MedInc', hue='cluster',palette='viridis')
plt.title('X_train: Longitud vs MedInc')
plt.xlabel('Longitude')
plt.ylabel('MedInc')

# Gráfico 3: Gráfico de cajas para MedHouseVal por cluster
plt.subplot(1, 3, 3)
sns.scatterplot(data=X_train, x='Latitude', y='MedInc', hue='cluster',palette='viridis')
plt.title('X_train: Latitude vs MedInc')
plt.xlabel('Latitude')
plt.ylabel('MedInc')
plt.show()

# %%
y_test=list(model.predict(X_test))
X_test['cluster']=y_test
X_test
# Out:
#        MedInc  Latitude  Longitude  cluster
# 20046  1.6812     36.06    -119.01        3
# 3024   2.5313     35.14    -119.46        3
# 15663  3.4801     37.80    -122.44        5
# 20484  5.7376     34.28    -118.72        2
# 9814   3.7250     36.62    -121.93        5
# ...       ...       ...        ...      ...
# 15362  4.6050     33.36    -117.22        1
# 16623  2.7266     35.36    -120.83        5
# 18086  9.2298     37.31    -122.05        4
# 2144   2.7850     36.77    -119.76        5
# 3665   3.5521     34.22    -118.37        1
#
# [4128 rows x 4 columns]

# %%
plt.figure(figsize=(18, 10))

plt.subplot(2, 3, 1)
sns.scatterplot(data=X_train, x='Longitude', y='Latitude', hue='cluster', palette='viridis')
plt.title('X_train: Longitud vs Latitud')
plt.xlabel('Longitud')
plt.ylabel('Latitud')

plt.subplot(2, 3, 2)
sns.scatterplot(data=X_train, x='Longitude', y='MedInc', hue='cluster', palette='viridis')
plt.title('X_train: Longitud vs. MedInc')
plt.xlabel('Longitude')
plt.ylabel('MedInc')

plt.subplot(2, 3, 3)
sns.scatterplot(data=X_train, x='Latitude', y='MedInc', hue='cluster', palette='viridis')
plt.title('X_train: Latitud vs. MedInc')
plt.xlabel('Latitude')
plt.ylabel('MedInc')

# Gráficos para X_test
plt.subplot(2, 3, 4)
sns.scatterplot(data=X_test, x='Longitude', y='Latitude', hue='cluster', palette='viridis')
plt.title('X_test: Longitud vs. Latitud')
plt.xlabel('Longitud')
plt.ylabel('Latitud')

plt.subplot(2, 3, 5)
sns.scatterplot(data=X_test, x='Longitude', y='MedInc', hue='cluster', palette='viridis')
plt.title('X_test: Longitud vs. MedInc')
plt.xlabel('Longitude')
plt.ylabel('MedInc')

plt.subplot(2, 3, 6)
sns.scatterplot(data=X_test, x='Latitude', y='MedInc', hue='cluster', palette='viridis')
plt.title('X_test: Latitud vs. MedInc ')
plt.xlabel('Latitude')
plt.ylabel('MedInc')

# Ajustar el diseño
plt.tight_layout()
plt.show()

# %% [markdown]
# Gracias a los gráficos podemos ver que el modelo tiene un buen desempeño a la hora de clasificar datos nuevos.

# %% [markdown]
# Ya que he obtenido una clasificación de los datos en un total de 6 cluster usando Kmeans, usaré un modelo de arboles ya que estos pueden trabajar con datos no normalizados.

# %%
model_tree=DecisionTreeClassifier(random_state = 42)
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
fig = plt.figure(figsize=(15,15))

tree.plot_tree(model_tree, feature_names = list(X_train.columns), class_names = ["0", "1", "2", "3", "4", "5"], filled = True)

plt.show()

# %%
def get_metrics(y_train, y_test, y_pred_train, y_pred_test):
    # Calcular métricas para el conjunto de entrenamiento
    train_accuracy = accuracy_score(y_train, y_pred_train)
    train_f1 = f1_score(y_train, y_pred_train, average='weighted')
    train_precision = precision_score(y_train, y_pred_train, average='weighted')
    train_recall = recall_score(y_train, y_pred_train, average='weighted')

    # Calcular métricas para el conjunto de prueba
    test_accuracy = accuracy_score(y_test, y_pred_test)
    test_f1 = f1_score(y_test, y_pred_test, average='weighted')
    test_precision = precision_score(y_test, y_pred_test, average='weighted')
    test_recall = recall_score(y_test, y_pred_test, average='weighted')

    # Calcular la diferencia entre métricas de entrenamiento y prueba
    diff_accuracy = train_accuracy - test_accuracy
    diff_f1 = train_f1 - test_f1
    diff_precision = train_precision - test_precision
    diff_recall = train_recall - test_recall

    # Crear un DataFrame con los resultados
    metrics_df = pd.DataFrame([[train_accuracy, train_f1,  train_precision, train_recall],[test_accuracy, test_f1,  test_precision, test_recall],[diff_accuracy, diff_f1, diff_precision, diff_recall]],
                              columns = ['Accuracy', 'F1', 'Precision', 'Recall'],
                              index = ['Train','Test', 'Diferencia'])

    return metrics_df

# %%
y_pred_train = model_tree.predict(X_train)
y_pred_test= model_tree.predict(X_test)

# %%
get_metrics(y_train, y_test, y_pred_train, y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 get_metrics(y_train, y_test, y_pred_train, y_pred_test)
#
# Cell In[94], line 7, in get_metrics(y_train, y_test, y_pred_train, y_pred_test)
#       5 train_precision = precision_score(y_train, y_pred_train, average='weighted')
#       6 train_recall = recall_score(y_train, y_pred_train, average='weighted')
# ----> 7 train_specificity = specificity_score(y_train, y_pred_train)
#       9 # Calcular métricas para el conjunto de prueba
#      10 test_accuracy = accuracy_score(y_test, y_pred_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
# ...
